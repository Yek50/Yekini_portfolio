# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
data=pd.read_csv('super market.csv',encoding='latin-1')

# %%
data.head(2)
# Out:
#    Row ID        Order ID  Order Date Ship Date.1       Ship Mode Customer ID  \
# 0    8223  CA-2014-152905   2/18/2014   2/24/2014  Standard Class    AB-10015
# 1    8802  CA-2016-140935  11/10/2016  11/12/2016     First Class    AB-10015
#
#    Customer Name   Segment        Country           City  ... Postal Code  \
# 0  Aaron Bergman  Consumer  United States      Arlington  ...       76017
# 1  Aaron Bergman  Consumer  United States  Oklahoma City  ...       73120
#
#     Region       Product ID         Category Sub-Category        Product Name  \
# 0  Central  OFF-ST-10000321  Office Supplies      Storage  Akro Stacking Bins
# 1  Central  TEC-PH-10000562       Technology       Phones    Samsung Convoy 3
#
#      Sales  Quantity  Discount   Profit
# 0   12.624         2       0.2  -2.5248
# 1  221.980         2       0.0  62.1544
#
# [2 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date.1    9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
data['Month']=pd.DatetimeIndex(data['Order Date']).month_name()

# %%
data.head(2)
# Out:
#    Row ID        Order ID Order Date Ship Date.1       Ship Mode Customer ID  \
# 0    8223  CA-2014-152905 2014-02-18   2/24/2014  Standard Class    AB-10015
# 1    8802  CA-2016-140935 2016-11-10  11/12/2016     First Class    AB-10015
#
#    Customer Name   Segment        Country           City  ...   Region  \
# 0  Aaron Bergman  Consumer  United States      Arlington  ...  Central
# 1  Aaron Bergman  Consumer  United States  Oklahoma City  ...  Central
#
#         Product ID         Category Sub-Category        Product Name    Sales  \
# 0  OFF-ST-10000321  Office Supplies      Storage  Akro Stacking Bins   12.624
# 1  TEC-PH-10000562       Technology       Phones    Samsung Convoy 3  221.980
#
#   Quantity  Discount   Profit     Month
# 0        2       0.2  -2.5248  February
# 1        2       0.0  62.1544  November
#
# [2 rows x 22 columns]

# %%
data['Ship Date.1']=pd.to_datetime(data['Ship Date.1'])

# %%
data['Class Interval']=data['Order Date']- data['Ship Date.1']

# %%
data.head(2)
# Out:
#    Row ID        Order ID Order Date Ship Date.1       Ship Mode Customer ID  \
# 0    8223  CA-2014-152905 2014-02-18  2014-02-24  Standard Class    AB-10015
# 1    8802  CA-2016-140935 2016-11-10  2016-11-12     First Class    AB-10015
#
#    Customer Name   Segment        Country           City  ...  \
# 0  Aaron Bergman  Consumer  United States      Arlington  ...
# 1  Aaron Bergman  Consumer  United States  Oklahoma City  ...
#
#         Product ID         Category Sub-Category        Product Name    Sales  \
# 0  OFF-ST-10000321  Office Supplies      Storage  Akro Stacking Bins   12.624
# 1  TEC-PH-10000562       Technology       Phones    Samsung Convoy 3  221.980
#
#   Quantity Discount   Profit     Month  Class Interval
# 0        2      0.2  -2.5248  February         -6 days
# 1        2      0.0  62.1544  November         -2 days
#
# [2 rows x 23 columns]

# %%
data['ClassInterval']=data['Ship Date.1']- data['Order Date']

# %%
data.head(2)
# Out:
#    Row ID        Order ID Order Date Ship Date.1       Ship Mode Customer ID  \
# 0    8223  CA-2014-152905 2014-02-18  2014-02-24  Standard Class    AB-10015
# 1    8802  CA-2016-140935 2016-11-10  2016-11-12     First Class    AB-10015
#
#    Customer Name   Segment        Country           City  ...  \
# 0  Aaron Bergman  Consumer  United States      Arlington  ...
# 1  Aaron Bergman  Consumer  United States  Oklahoma City  ...
#
#           Category  Sub-Category        Product Name    Sales Quantity  \
# 0  Office Supplies       Storage  Akro Stacking Bins   12.624        2
# 1       Technology        Phones    Samsung Convoy 3  221.980        2
#
#   Discount   Profit     Month  Class Interval  ClassInterval
# 0      0.2  -2.5248  February         -6 days         6 days
# 1      0.0  62.1544  November         -2 days         2 days
#
# [2 rows x 24 columns]

# %%
data=data.drop('Class Interval',axis=1)

# %%
data.head(1)
# Out:
#    Row ID        Order ID Order Date Ship Date.1       Ship Mode Customer ID  \
# 0    8223  CA-2014-152905 2014-02-18  2014-02-24  Standard Class    AB-10015
#
#    Customer Name   Segment        Country       City  ...       Product ID  \
# 0  Aaron Bergman  Consumer  United States  Arlington  ...  OFF-ST-10000321
#
#           Category Sub-Category        Product Name   Sales Quantity Discount  \
# 0  Office Supplies      Storage  Akro Stacking Bins  12.624        2      0.2
#
#    Profit     Month  ClassInterval
# 0 -2.5248  February         6 days
#
# [1 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date.1', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Month',
#        'ClassInterval'],
#       dtype='object')

# %%
data['']
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)
