# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
df=pd.read_csv(r'C:\Users\HP\Downloads\archive (3)\agricultural_raw_material.csv')

df.head()
# Out:
#     Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0  Apr-90            482.34                          -         236
# 1  May-90            447.26                     -7.27%         234
# 2  Jun-90            440.99                     -1.40%         216
# 3  Jul-90            418.44                     -5.11%         205
# 4  Aug-90            418.44                      0.00%         198
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    -          1.83                     -        1,071.63
# 1               -0.85%          1.89                 3.28%        1,057.18
# 2               -7.69%          1.99                 5.29%          898.24
# 3               -5.09%          2.01                 1.01%          895.83
# 4               -3.41%          1.79               -10.95%          951.22
#
#   Fine wool price % Change  Hard log Price  ... Plywood Price  \
# 0                        -          161.20  ...        312.36
# 1                   -1.35%          172.86  ...        350.12
# 2                  -15.03%          181.67  ...        373.94
# 3                   -0.27%          187.96  ...        378.48
# 4                    6.18%          186.13  ...        364.60
#
#    Plywood price % Change Rubber Price  Rubber price % Change Softlog Price  \
# 0                       -         0.84                      -        120.66
# 1                  12.09%         0.85                  1.19%        124.28
# 2                   6.80%         0.85                  0.00%        129.45
# 3                   1.21%         0.86                  1.18%        124.23
# 4                  -3.67%         0.88                  2.33%        129.70
#
#    Softlog price % Change Soft sawnwood Price  Soft sawnwood price % Change  \
# 0                       -              218.76                             -
# 1                   3.00%              213.00                        -2.63%
# 2                   4.16%              200.00                        -6.10%
# 3                  -4.03%              210.05                         5.03%
# 4                   4.40%              208.30                        -0.83%
#
#   Wood pulp Price  Wood pulp price % Change
# 0          829.29                         -
# 1          842.51                     1.59%
# 2          831.35                    -1.32%
# 3          798.83                    -3.91%
# 4          818.74                     2.49%
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         361 non-null    object
#  1   Coarse wool Price             327 non-null    object
#  2   Coarse wool price % Change    327 non-null    object
#  3   Copra Price                   339 non-null    object
#  4   Copra price % Change          339 non-null    object
#  5   Cotton Price                  361 non-null    float64
#  6   Cotton price % Change         361 non-null    object
#  7   Fine wool Price               327 non-null    object
#  8   Fine wool price % Change      327 non-null    object
#  9   Hard log Price                361 non-null    float64
#  10  Hard log price % Change       361 non-null    object
#  11  Hard sawnwood Price           327 non-null    float64
#  12  Hard sawnwood price % Change  327 non-null    object
#  13  Hide Price                    327 non-null    float64
#  14  Hide price % change           327 non-null    object
#  15  Plywood Price                 361 non-null    float64
#  16  Plywood price % Change        361 non-null    object
#  17  Rubber Price                  361 non-null    float64
#  18  Rubber price % Change         361 non-null    object
#  19  Softlog Price                 327 non-null    float64
#  20  Softlog price % Change        327 non-null    object
#  21  Soft sawnwood Price           327 non-null    float64
#  22  Soft sawnwood price % Change  327 non-null    object
#  23  Wood pulp Price               360 non-null    float64
#  24  Wood pulp price % Change      360 non-null    object
# dtypes: float64(9), object(16)
# memory usage: 70.6+ KB

# %%
df.isna().sum()
# Out:
# Month                            0
# Coarse wool Price               34
# Coarse wool price % Change      34
# Copra Price                     22
# Copra price % Change            22
# Cotton Price                     0
# Cotton price % Change            0
# Fine wool Price                 34
# Fine wool price % Change        34
# Hard log Price                   0
# Hard log price % Change          0
# Hard sawnwood Price             34
# Hard sawnwood price % Change    34
# Hide Price                      34
# Hide price % change             34
# Plywood Price                    0
# Plywood price % Change           0
# Rubber Price                     0
# Rubber price % Change            0
# Softlog Price                   34
# Softlog price % Change          34
# Soft sawnwood Price             34
# Soft sawnwood price % Change    34
# Wood pulp Price                  1
# Wood pulp price % Change         1
# dtype: int64

# %%
df.head(3)
# Out:
#     Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0  Apr-90            482.34                          -         236
# 1  May-90            447.26                     -7.27%         234
# 2  Jun-90            440.99                     -1.40%         216
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    -          1.83                     -        1,071.63
# 1               -0.85%          1.89                 3.28%        1,057.18
# 2               -7.69%          1.99                 5.29%          898.24
#
#   Fine wool price % Change  Hard log Price  ... Plywood Price  \
# 0                        -          161.20  ...        312.36
# 1                   -1.35%          172.86  ...        350.12
# 2                  -15.03%          181.67  ...        373.94
#
#    Plywood price % Change Rubber Price  Rubber price % Change Softlog Price  \
# 0                       -         0.84                      -        120.66
# 1                  12.09%         0.85                  1.19%        124.28
# 2                   6.80%         0.85                  0.00%        129.45
#
#    Softlog price % Change Soft sawnwood Price  Soft sawnwood price % Change  \
# 0                       -              218.76                             -
# 1                   3.00%              213.00                        -2.63%
# 2                   4.16%              200.00                        -6.10%
#
#   Wood pulp Price  Wood pulp price % Change
# 0          829.29                         -
# 1          842.51                     1.59%
# 2          831.35                    -1.32%
#
# [3 rows x 25 columns]

# %%
df=df.replace(',','',regex=True)
df=df.replace('-','',regex=True)
df=df.replace('%','',regex=True)
df=df.replace('',np.nan)

# %%
df
# Out:
#      Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0    Apr90            482.34                        NaN         236
# 1    May90            447.26                       7.27         234
# 2    Jun90            440.99                       1.40         216
# 3    Jul90            418.44                       5.11         205
# 4    Aug90            418.44                       0.00         198
# ..     ...               ...                        ...         ...
# 356  Dec19               NaN                        NaN         NaN
# 357  Jan20               NaN                        NaN         NaN
# 358  Feb20               NaN                        NaN         NaN
# 359  Mar20               NaN                        NaN         NaN
# 360  Apr20               NaN                        NaN         NaN
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    NaN          1.83                   NaN         1071.63
# 1                   0.85          1.89                  3.28         1057.18
# 2                   7.69          1.99                  5.29          898.24
# 3                   5.09          2.01                  1.01          895.83
# 4                   3.41          1.79                 10.95          951.22
# ..                   ...           ...                   ...             ...
# 356                  NaN          1.67                  1.21             NaN
# 357                  NaN          1.74                  4.19             NaN
# 358                  NaN          1.69                  2.87             NaN
# 359                  NaN          1.49                 11.83             NaN
# 360                  NaN          1.40                  6.04             NaN
#
#     Fine wool price % Change  Hard log Price  ... Plywood Price  \
# 0                        NaN          161.20  ...        312.36
# 1                       1.35          172.86  ...        350.12
# 2                      15.03          181.67  ...        373.94
# 3                       0.27          187.96  ...        378.48
# 4                       6.18          186.13  ...        364.60
# ..                       ...             ...  ...           ...
# 356                      NaN          272.80  ...        500.37
# 357                      NaN          272.40  ...        499.64
# 358                      NaN          270.56  ...        496.28
# 359                      NaN          276.93  ...        507.96
# 360                      NaN          276.24  ...        506.68
#
#      Plywood price % Change Rubber Price  Rubber price % Change Softlog Price  \
# 0                       NaN         0.84                    NaN        120.66
# 1                     12.09         0.85                   1.19        124.28
# 2                      6.80         0.85                   0.00        129.45
# 3                      1.21         0.86                   1.18        124.23
# 4                      3.67         0.88                   2.33        129.70
# ..                      ...          ...                    ...           ...
# 356                    0.22         1.66                   7.79           NaN
# 357                    0.15         1.68                   1.20           NaN
# 358                    0.67         1.61                   4.17           NaN
# 359                    2.35         1.50                   6.83           NaN
# 360                    0.25         1.33                  11.33           NaN
#
#      Softlog price % Change Soft sawnwood Price  Soft sawnwood price % Change  \
# 0                       NaN              218.76                           NaN
# 1                      3.00              213.00                          2.63
# 2                      4.16              200.00                          6.10
# 3                      4.03              210.05                          5.03
# 4                      4.40              208.30                          0.83
# ..                      ...                 ...                           ...
# 356                     NaN                 NaN                           NaN
# 357                     NaN                 NaN                           NaN
# 358                     NaN                 NaN                           NaN
# 359                     NaN                 NaN                           NaN
# 360                     NaN                 NaN                           NaN
#
#     Wood pulp Price  Wood pulp price % Change
# 0            829.29                       NaN
# 1            842.51                      1.59
# 2            831.35                      1.32
# 3            798.83                      3.91
# 4            818.74                      2.49
# ..              ...                       ...
# 356          875.00                      0.00
# 357          875.00                      0.00
# 358          875.00                      0.00
# 359          875.00                      0.00
# 360             NaN                       NaN
#
# [361 rows x 25 columns]

# %%
df=df.fillna(0)

# %%
df.head()
# Out:
#    Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0  Apr90            482.34                          0         236
# 1  May90            447.26                       7.27         234
# 2  Jun90            440.99                       1.40         216
# 3  Jul90            418.44                       5.11         205
# 4  Aug90            418.44                       0.00         198
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    0          1.83                     0         1071.63
# 1                 0.85          1.89                  3.28         1057.18
# 2                 7.69          1.99                  5.29          898.24
# 3                 5.09          2.01                  1.01          895.83
# 4                 3.41          1.79                 10.95          951.22
#
#   Fine wool price % Change  Hard log Price  ... Plywood Price  \
# 0                        0          161.20  ...        312.36
# 1                     1.35          172.86  ...        350.12
# 2                    15.03          181.67  ...        373.94
# 3                     0.27          187.96  ...        378.48
# 4                     6.18          186.13  ...        364.60
#
#    Plywood price % Change Rubber Price  Rubber price % Change Softlog Price  \
# 0                       0         0.84                      0        120.66
# 1                   12.09         0.85                   1.19        124.28
# 2                    6.80         0.85                   0.00        129.45
# 3                    1.21         0.86                   1.18        124.23
# 4                    3.67         0.88                   2.33        129.70
#
#    Softlog price % Change Soft sawnwood Price  Soft sawnwood price % Change  \
# 0                       0              218.76                             0
# 1                    3.00              213.00                          2.63
# 2                    4.16              200.00                          6.10
# 3                    4.03              210.05                          5.03
# 4                    4.40              208.30                          0.83
#
#   Wood pulp Price  Wood pulp price % Change
# 0          829.29                         0
# 1          842.51                      1.59
# 2          831.35                      1.32
# 3          798.83                      3.91
# 4          818.74                      2.49
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         361 non-null    object
#  1   Coarse wool Price             361 non-null    object
#  2   Coarse wool price % Change    361 non-null    object
#  3   Copra Price                   361 non-null    object
#  4   Copra price % Change          361 non-null    object
#  5   Cotton Price                  361 non-null    float64
#  6   Cotton price % Change         361 non-null    object
#  7   Fine wool Price               361 non-null    object
#  8   Fine wool price % Change      361 non-null    object
#  9   Hard log Price                361 non-null    float64
#  10  Hard log price % Change       361 non-null    object
#  11  Hard sawnwood Price           361 non-null    float64
#  12  Hard sawnwood price % Change  361 non-null    object
#  13  Hide Price                    361 non-null    float64
#  14  Hide price % change           361 non-null    object
#  15  Plywood Price                 361 non-null    float64
#  16  Plywood price % Change        361 non-null    object
#  17  Rubber Price                  361 non-null    float64
#  18  Rubber price % Change         361 non-null    object
#  19  Softlog Price                 361 non-null    float64
#  20  Softlog price % Change        361 non-null    object
#  21  Soft sawnwood Price           361 non-null    float64
#  22  Soft sawnwood price % Change  361 non-null    object
#  23  Wood pulp Price               361 non-null    float64
#  24  Wood pulp price % Change      361 non-null    object
# dtypes: float64(9), object(16)
# memory usage: 70.6+ KB

# %%
df.columns
# Out:
# Index(['Month', 'Coarse wool Price', 'Coarse wool price % Change',
#        'Copra Price', 'Copra price % Change', 'Cotton Price',
#        'Cotton price % Change', 'Fine wool Price', 'Fine wool price % Change',
#        'Hard log Price', 'Hard log price % Change', 'Hard sawnwood Price',
#        'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
#        'Plywood Price', 'Plywood price % Change', 'Rubber Price',
#        'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
#        'Soft sawnwood Price', 'Soft sawnwood price % Change',
#        'Wood pulp Price', 'Wood pulp price % Change'],
#       dtype='object')

# %%
list=['Coarse wool Price', 'Coarse wool price % Change',
       'Copra Price', 'Copra price % Change', 'Cotton Price',
       'Cotton price % Change', 'Fine wool Price', 'Fine wool price % Change',
       'Hard log Price', 'Hard log price % Change', 'Hard sawnwood Price',
       'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
       'Plywood Price', 'Plywood price % Change', 'Rubber Price',
       'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
       'Soft sawnwood Price', 'Soft sawnwood price % Change',
       'Wood pulp Price', 'Wood pulp price % Change']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         361 non-null    object
#  1   Coarse wool Price             361 non-null    object
#  2   Coarse wool price % Change    361 non-null    object
#  3   Copra Price                   361 non-null    object
#  4   Copra price % Change          361 non-null    object
#  5   Cotton Price                  361 non-null    float64
#  6   Cotton price % Change         361 non-null    object
#  7   Fine wool Price               361 non-null    object
#  8   Fine wool price % Change      361 non-null    object
#  9   Hard log Price                361 non-null    float64
#  10  Hard log price % Change       361 non-null    object
#  11  Hard sawnwood Price           361 non-null    float64
#  12  Hard sawnwood price % Change  361 non-null    object
#  13  Hide Price                    361 non-null    float64
#  14  Hide price % change           361 non-null    object
#  15  Plywood Price                 361 non-null    float64
#  16  Plywood price % Change        361 non-null    object
#  17  Rubber Price                  361 non-null    float64
#  18  Rubber price % Change         361 non-null    object
#  19  Softlog Price                 361 non-null    float64
#  20  Softlog price % Change        361 non-null    object
#  21  Soft sawnwood Price           361 non-null    float64
#  22  Soft sawnwood price % Change  361 non-null    object
#  23  Wood pulp Price               361 non-null    float64
#  24  Wood pulp price % Change      361 non-null    object
# dtypes: float64(9), object(16)
# memory usage: 70.6+ KB

# %%
df['Month']=pd.to_datetime(df['Month'].str.upper(),yearfirst=False,format='%b%y')

# %%
df.head(2)
# Out:
#        Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0 1990-04-01            482.34                          0         236
# 1 1990-05-01            447.26                       7.27         234
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    0          1.83                     0         1071.63
# 1                 0.85          1.89                  3.28         1057.18
#
#   Fine wool price % Change  Hard log Price  ... Plywood Price  \
# 0                        0          161.20  ...        312.36
# 1                     1.35          172.86  ...        350.12
#
#    Plywood price % Change Rubber Price  Rubber price % Change Softlog Price  \
# 0                       0         0.84                      0        120.66
# 1                   12.09         0.85                   1.19        124.28
#
#    Softlog price % Change Soft sawnwood Price  Soft sawnwood price % Change  \
# 0                       0              218.76                             0
# 1                    3.00              213.00                          2.63
#
#   Wood pulp Price  Wood pulp price % Change
# 0          829.29                         0
# 1          842.51                      1.59
#
# [2 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         361 non-null    datetime64[ns]
#  1   Coarse wool Price             361 non-null    object
#  2   Coarse wool price % Change    361 non-null    object
#  3   Copra Price                   361 non-null    object
#  4   Copra price % Change          361 non-null    object
#  5   Cotton Price                  361 non-null    float64
#  6   Cotton price % Change         361 non-null    object
#  7   Fine wool Price               361 non-null    object
#  8   Fine wool price % Change      361 non-null    object
#  9   Hard log Price                361 non-null    float64
#  10  Hard log price % Change       361 non-null    object
#  11  Hard sawnwood Price           361 non-null    float64
#  12  Hard sawnwood price % Change  361 non-null    object
#  13  Hide Price                    361 non-null    float64
#  14  Hide price % change           361 non-null    object
#  15  Plywood Price                 361 non-null    float64
#  16  Plywood price % Change        361 non-null    object
#  17  Rubber Price                  361 non-null    float64
#  18  Rubber price % Change         361 non-null    object
#  19  Softlog Price                 361 non-null    float64
#  20  Softlog price % Change        361 non-null    object
#  21  Soft sawnwood Price           361 non-null    float64
#  22  Soft sawnwood price % Change  361 non-null    object
#  23  Wood pulp Price               361 non-null    float64
#  24  Wood pulp price % Change      361 non-null    object
# dtypes: datetime64[ns](1), float64(9), object(15)
# memory usage: 70.6+ KB

# %%
df.columns
# Out:
# Index(['Month', 'Coarse wool Price', 'Coarse wool price % Change',
#        'Copra Price', 'Copra price % Change', 'Cotton Price',
#        'Cotton price % Change', 'Fine wool Price', 'Fine wool price % Change',
#        'Hard log Price', 'Hard log price % Change', 'Hard sawnwood Price',
#        'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
#        'Plywood Price', 'Plywood price % Change', 'Rubber Price',
#        'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
#        'Soft sawnwood Price', 'Soft sawnwood price % Change',
#        'Wood pulp Price', 'Wood pulp price % Change'],
#       dtype='object')

# %%
df[list]=df[list].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         361 non-null    datetime64[ns]
#  1   Coarse wool Price             361 non-null    float64
#  2   Coarse wool price % Change    361 non-null    float64
#  3   Copra Price                   361 non-null    float64
#  4   Copra price % Change          361 non-null    float64
#  5   Cotton Price                  361 non-null    float64
#  6   Cotton price % Change         361 non-null    float64
#  7   Fine wool Price               361 non-null    float64
#  8   Fine wool price % Change      361 non-null    float64
#  9   Hard log Price                361 non-null    float64
#  10  Hard log price % Change       361 non-null    float64
#  11  Hard sawnwood Price           361 non-null    float64
#  12  Hard sawnwood price % Change  361 non-null    float64
#  13  Hide Price                    361 non-null    float64
#  14  Hide price % change           361 non-null    float64
#  15  Plywood Price                 361 non-null    float64
#  16  Plywood price % Change        361 non-null    float64
#  17  Rubber Price                  361 non-null    float64
#  18  Rubber price % Change         361 non-null    float64
#  19  Softlog Price                 361 non-null    float64
#  20  Softlog price % Change        361 non-null    float64
#  21  Soft sawnwood Price           361 non-null    float64
#  22  Soft sawnwood price % Change  361 non-null    float64
#  23  Wood pulp Price               361 non-null    float64
#  24  Wood pulp price % Change      361 non-null    float64
# dtypes: datetime64[ns](1), float64(24)
# memory usage: 70.6 KB

# %%
dframe=df.set_index('Month')

# %%
dframe
# Out:
#             Coarse wool Price  Coarse wool price % Change  Copra Price  \
# Month
# 1990-04-01             482.34                        0.00        236.0
# 1990-05-01             447.26                        7.27        234.0
# 1990-06-01             440.99                        1.40        216.0
# 1990-07-01             418.44                        5.11        205.0
# 1990-08-01             418.44                        0.00        198.0
# ...                       ...                         ...          ...
# 2019-12-01               0.00                        0.00          0.0
# 2020-01-01               0.00                        0.00          0.0
# 2020-02-01               0.00                        0.00          0.0
# 2020-03-01               0.00                        0.00          0.0
# 2020-04-01               0.00                        0.00          0.0
#
#             Copra price % Change  Cotton Price  Cotton price % Change  \
# Month
# 1990-04-01                  0.00          1.83                   0.00
# 1990-05-01                  0.85          1.89                   3.28
# 1990-06-01                  7.69          1.99                   5.29
# 1990-07-01                  5.09          2.01                   1.01
# 1990-08-01                  3.41          1.79                  10.95
# ...                          ...           ...                    ...
# 2019-12-01                  0.00          1.67                   1.21
# 2020-01-01                  0.00          1.74                   4.19
# 2020-02-01                  0.00          1.69                   2.87
# 2020-03-01                  0.00          1.49                  11.83
# 2020-04-01                  0.00          1.40                   6.04
#
#             Fine wool Price  Fine wool price % Change  Hard log Price  \
# Month
# 1990-04-01          1071.63                      0.00          161.20
# 1990-05-01          1057.18                      1.35          172.86
# 1990-06-01           898.24                     15.03          181.67
# 1990-07-01           895.83                      0.27          187.96
# 1990-08-01           951.22                      6.18          186.13
# ...                     ...                       ...             ...
# 2019-12-01             0.00                      0.00          272.80
# 2020-01-01             0.00                      0.00          272.40
# 2020-02-01             0.00                      0.00          270.56
# 2020-03-01             0.00                      0.00          276.93
# 2020-04-01             0.00                      0.00          276.24
#
#             Hard log price % Change  ...  Plywood Price  \
# Month                                ...
# 1990-04-01                     0.00  ...         312.36
# 1990-05-01                     7.23  ...         350.12
# 1990-06-01                     5.10  ...         373.94
# 1990-07-01                     3.46  ...         378.48
# 1990-08-01                     0.97  ...         364.60
# ...                             ...  ...            ...
# 2019-12-01                     0.22  ...         500.37
# 2020-01-01                     0.15  ...         499.64
# 2020-02-01                     0.68  ...         496.28
# 2020-03-01                     2.35  ...         507.96
# 2020-04-01                     0.25  ...         506.68
#
#             Plywood price % Change  Rubber Price  Rubber price % Change  \
# Month
# 1990-04-01                    0.00          0.84                   0.00
# 1990-05-01                   12.09          0.85                   1.19
# 1990-06-01                    6.80          0.85                   0.00
# 1990-07-01                    1.21          0.86                   1.18
# 1990-08-01                    3.67          0.88                   2.33
# ...                            ...           ...                    ...
# 2019-12-01                    0.22          1.66                   7.79
# 2020-01-01                    0.15          1.68                   1.20
# 2020-02-01                    0.67          1.61                   4.17
# 2020-03-01                    2.35          1.50                   6.83
# 2020-04-01                    0.25          1.33                  11.33
#
#             Softlog Price  Softlog price % Change  Soft sawnwood Price  \
# Month
# 1990-04-01         120.66                    0.00               218.76
# 1990-05-01         124.28                    3.00               213.00
# 1990-06-01         129.45                    4.16               200.00
# 1990-07-01         124.23                    4.03               210.05
# 1990-08-01         129.70                    4.40               208.30
# ...                   ...                     ...                  ...
# 2019-12-01           0.00                    0.00                 0.00
# 2020-01-01           0.00                    0.00                 0.00
# 2020-02-01           0.00                    0.00                 0.00
# 2020-03-01           0.00                    0.00                 0.00
# 2020-04-01           0.00                    0.00                 0.00
#
#             Soft sawnwood price % Change  Wood pulp Price  \
# Month
# 1990-04-01                          0.00           829.29
# 1990-05-01                          2.63           842.51
# 1990-06-01                          6.10           831.35
# 1990-07-01                          5.03           798.83
# 1990-08-01                          0.83           818.74
# ...                                  ...              ...
# 2019-12-01                          0.00           875.00
# 2020-01-01                          0.00           875.00
# 2020-02-01                          0.00           875.00
# 2020-03-01                          0.00           875.00
# 2020-04-01                          0.00             0.00
#
#             Wood pulp price % Change
# Month
# 1990-04-01                      0.00
# 1990-05-01                      1.59
# 1990-06-01                      1.32
# 1990-07-01                      3.91
# 1990-08-01                      2.49
# ...                              ...
# 2019-12-01                      0.00
# 2020-01-01                      0.00
# 2020-02-01                      0.00
# 2020-03-01                      0.00
# 2020-04-01                      0.00
#
# [361 rows x 24 columns]

# %%
axes=dframe[['Coarse wool Price','Coarse wool price % Change']].plot(figsize=(14,9),subplots=True)

# %%
dframe.columns
# Out:
# Index(['Coarse wool Price', 'Coarse wool price % Change', 'Copra Price',
#        'Copra price % Change', 'Cotton Price', 'Cotton price % Change',
#        'Fine wool Price', 'Fine wool price % Change', 'Hard log Price',
#        'Hard log price % Change', 'Hard sawnwood Price',
#        'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
#        'Plywood Price', 'Plywood price % Change', 'Rubber Price',
#        'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
#        'Soft sawnwood Price', 'Soft sawnwood price % Change',
#        'Wood pulp Price', 'Wood pulp price % Change'],
#       dtype='object')

# %%
Range=['Coarse wool price % Change','Copra price % Change','Cotton price % Change','Fine wool price % Change','Hard log price % Change','Hide price % change','Plywood price % Change','Softlog price % Change','Soft sawnwood price % Change','Wood pulp price % Change']

for i in range(len(Range)):
    plt.figure(figsize=(14,9))
    dframe[Range[i]].hist(figsize=(12,9))
    plt.xlabel('Change In Percentage')
    plt.ylabel('Counts')
    plt.legend(Range[i:],loc='upper center',bbox_to_anchor=(1.5,1))

# %%
dframe
# Out:
#             Coarse wool Price  Coarse wool price % Change  Copra Price  \
# Month
# 1990-04-01             482.34                        0.00        236.0
# 1990-05-01             447.26                        7.27        234.0
# 1990-06-01             440.99                        1.40        216.0
# 1990-07-01             418.44                        5.11        205.0
# 1990-08-01             418.44                        0.00        198.0
# ...                       ...                         ...          ...
# 2019-12-01               0.00                        0.00          0.0
# 2020-01-01               0.00                        0.00          0.0
# 2020-02-01               0.00                        0.00          0.0
# 2020-03-01               0.00                        0.00          0.0
# 2020-04-01               0.00                        0.00          0.0
#
#             Copra price % Change  Cotton Price  Cotton price % Change  \
# Month
# 1990-04-01                  0.00          1.83                   0.00
# 1990-05-01                  0.85          1.89                   3.28
# 1990-06-01                  7.69          1.99                   5.29
# 1990-07-01                  5.09          2.01                   1.01
# 1990-08-01                  3.41          1.79                  10.95
# ...                          ...           ...                    ...
# 2019-12-01                  0.00          1.67                   1.21
# 2020-01-01                  0.00          1.74                   4.19
# 2020-02-01                  0.00          1.69                   2.87
# 2020-03-01                  0.00          1.49                  11.83
# 2020-04-01                  0.00          1.40                   6.04
#
#             Fine wool Price  Fine wool price % Change  Hard log Price  \
# Month
# 1990-04-01          1071.63                      0.00          161.20
# 1990-05-01          1057.18                      1.35          172.86
# 1990-06-01           898.24                     15.03          181.67
# 1990-07-01           895.83                      0.27          187.96
# 1990-08-01           951.22                      6.18          186.13
# ...                     ...                       ...             ...
# 2019-12-01             0.00                      0.00          272.80
# 2020-01-01             0.00                      0.00          272.40
# 2020-02-01             0.00                      0.00          270.56
# 2020-03-01             0.00                      0.00          276.93
# 2020-04-01             0.00                      0.00          276.24
#
#             Hard log price % Change  ...  Plywood Price  \
# Month                                ...
# 1990-04-01                     0.00  ...         312.36
# 1990-05-01                     7.23  ...         350.12
# 1990-06-01                     5.10  ...         373.94
# 1990-07-01                     3.46  ...         378.48
# 1990-08-01                     0.97  ...         364.60
# ...                             ...  ...            ...
# 2019-12-01                     0.22  ...         500.37
# 2020-01-01                     0.15  ...         499.64
# 2020-02-01                     0.68  ...         496.28
# 2020-03-01                     2.35  ...         507.96
# 2020-04-01                     0.25  ...         506.68
#
#             Plywood price % Change  Rubber Price  Rubber price % Change  \
# Month
# 1990-04-01                    0.00          0.84                   0.00
# 1990-05-01                   12.09          0.85                   1.19
# 1990-06-01                    6.80          0.85                   0.00
# 1990-07-01                    1.21          0.86                   1.18
# 1990-08-01                    3.67          0.88                   2.33
# ...                            ...           ...                    ...
# 2019-12-01                    0.22          1.66                   7.79
# 2020-01-01                    0.15          1.68                   1.20
# 2020-02-01                    0.67          1.61                   4.17
# 2020-03-01                    2.35          1.50                   6.83
# 2020-04-01                    0.25          1.33                  11.33
#
#             Softlog Price  Softlog price % Change  Soft sawnwood Price  \
# Month
# 1990-04-01         120.66                    0.00               218.76
# 1990-05-01         124.28                    3.00               213.00
# 1990-06-01         129.45                    4.16               200.00
# 1990-07-01         124.23                    4.03               210.05
# 1990-08-01         129.70                    4.40               208.30
# ...                   ...                     ...                  ...
# 2019-12-01           0.00                    0.00                 0.00
# 2020-01-01           0.00                    0.00                 0.00
# 2020-02-01           0.00                    0.00                 0.00
# 2020-03-01           0.00                    0.00                 0.00
# 2020-04-01           0.00                    0.00                 0.00
#
#             Soft sawnwood price % Change  Wood pulp Price  \
# Month
# 1990-04-01                          0.00           829.29
# 1990-05-01                          2.63           842.51
# 1990-06-01                          6.10           831.35
# 1990-07-01                          5.03           798.83
# 1990-08-01                          0.83           818.74
# ...                                  ...              ...
# 2019-12-01                          0.00           875.00
# 2020-01-01                          0.00           875.00
# 2020-02-01                          0.00           875.00
# 2020-03-01                          0.00           875.00
# 2020-04-01                          0.00             0.00
#
#             Wood pulp price % Change
# Month
# 1990-04-01                      0.00
# 1990-05-01                      1.59
# 1990-06-01                      1.32
# 1990-07-01                      3.91
# 1990-08-01                      2.49
# ...                              ...
# 2019-12-01                      0.00
# 2020-01-01                      0.00
# 2020-02-01                      0.00
# 2020-03-01                      0.00
# 2020-04-01                      0.00
#
# [361 rows x 24 columns]

# %%
dframe.columns
# Out:
# Index(['Coarse wool Price', 'Coarse wool price % Change', 'Copra Price',
#        'Copra price % Change', 'Cotton Price', 'Cotton price % Change',
#        'Fine wool Price', 'Fine wool price % Change', 'Hard log Price',
#        'Hard log price % Change', 'Hard sawnwood Price',
#        'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
#        'Plywood Price', 'Plywood price % Change', 'Rubber Price',
#        'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
#        'Soft sawnwood Price', 'Soft sawnwood price % Change',
#        'Wood pulp Price', 'Wood pulp price % Change'],
#       dtype='object')

# %%
Materialist=['Coarse wool Price','Copra Price','Cotton Price','Fine wool Price','Hard log Price', 'Hard sawnwood Price','Hide Price','Plywood Price', 'Rubber Price','Softlog Price','Soft sawnwood Price','Wood pulp Price']

# %%
plt.figure(figsize=(18, 10))
materialslist=['Copra Price','Softlog Price','Rubber Price','Cotton Price','Coarse wool Price','Fine wool Price','Hard log Price','Hard sawnwood Price','Hide Price','Plywood Price','Soft sawnwood Price','Wood pulp Price']
for i in range(len(materialslist)):
    plt.subplot(4,3,i+1)
    plt.plot(dframe[materialslist[i]])
    plt.subplots_adjust( hspace=1 ,wspace=0.5)
    plt.title(materialslist[i])
    plt.xticks(rotation=90)
plt.suptitle("Raw-Materials price comparision")
# Out:
# Text(0.5, 0.98, 'Raw-Materials price comparision')

# %%
plt.figure(figsize=(18, 10))
plt.plot(dframe[['Cotton Price','Rubber Price']])
plt.title("Raw-Materials price comparision")
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Cotton Price','Rubber Price'],loc='upper center',bbox_to_anchor=(1.2,1))

# %%
plt.figure(figsize=(18, 10))
plt.plot(dframe[['Copra Price','Softlog Price','Rubber Price','Cotton Price','Coarse wool Price','Fine wool Price','Hard log Price','Hard sawnwood Price','Hide Price','Plywood Price','Soft sawnwood Price','Wood pulp Price']])
plt.title("Raw-Materials price comparision")
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Copra Price','Softlog Price','Rubber Price','Cotton Price','Coarse wool Price','Fine wool Price','Hard log Price','Hard sawnwood Price','Hide Price','Plywood Price','Soft sawnwood Price','Wood pulp Price'],loc='upper center',bbox_to_anchor=(1.2,1))

# %%
#plt.figure(figsize=(18,12))
#sns.scatterplot(df['Cotton Price'],df.index,hue=df['Fine wool Price']);
lowlist=['Cotton Price','Hide Price','Softlog Price','Hard log Price','Soft sawnwood Price','Rubber Price']
plt.figure(figsize=(18,12))
plt.ylabel('Prices')
plt.xlabel('Years')
#plt.legend(lowlist,loc='upper center',bbox_to_anchor=(1.2,1))
for i in range(len(lowlist)):
    sns.scatterplot(y=df[lowlist[i]],x=df.index);
    plt.legend(lowlist,loc='upper center',bbox_to_anchor=(1.2,1))

# %%
df.head(2)
# Out:
#        Month  Coarse wool Price  Coarse wool price % Change  Copra Price  \
# 0 1990-04-01             482.34                        0.00        236.0
# 1 1990-05-01             447.26                        7.27        234.0
#
#    Copra price % Change  Cotton Price  Cotton price % Change  Fine wool Price  \
# 0                  0.00          1.83                   0.00          1071.63
# 1                  0.85          1.89                   3.28          1057.18
#
#    Fine wool price % Change  Hard log Price  ...  Plywood Price  \
# 0                      0.00          161.20  ...         312.36
# 1                      1.35          172.86  ...         350.12
#
#    Plywood price % Change  Rubber Price  Rubber price % Change  Softlog Price  \
# 0                    0.00          0.84                   0.00         120.66
# 1                   12.09          0.85                   1.19         124.28
#
#    Softlog price % Change  Soft sawnwood Price  Soft sawnwood price % Change  \
# 0                     0.0               218.76                          0.00
# 1                     3.0               213.00                          2.63
#
#    Wood pulp Price  Wood pulp price % Change
# 0           829.29                      0.00
# 1           842.51                      1.59
#
# [2 rows x 25 columns]

# %%
df['Years']=pd.DatetimeIndex(df['Month']).year

# %%
df['Months_Name']=pd.DatetimeIndex(df['Month']).month_name()

# %%
# Out:
#        Month  Coarse wool Price  Coarse wool price % Change  Copra Price  \
# 0 1990-04-01             482.34                        0.00        236.0
# 1 1990-05-01             447.26                        7.27        234.0
# 2 1990-06-01             440.99                        1.40        216.0
#
#    Copra price % Change  Cotton Price  Cotton price % Change  Fine wool Price  \
# 0                  0.00          1.83                   0.00          1071.63
# 1                  0.85          1.89                   3.28          1057.18
# 2                  7.69          1.99                   5.29           898.24
#
#    Fine wool price % Change  Hard log Price  ...  Rubber Price  \
# 0                      0.00          161.20  ...          0.84
# 1                      1.35          172.86  ...          0.85
# 2                     15.03          181.67  ...          0.85
#
#    Rubber price % Change  Softlog Price  Softlog price % Change  \
# 0                   0.00         120.66                    0.00
# 1                   1.19         124.28                    3.00
# 2                   0.00         129.45                    4.16
#
#    Soft sawnwood Price  Soft sawnwood price % Change  Wood pulp Price  \
# 0               218.76                          0.00           829.29
# 1               213.00                          2.63           842.51
# 2               200.00                          6.10           831.35
#
#    Wood pulp price % Change  Years  Months_Name
# 0                      0.00   1990        April
# 1                      1.59   1990          May
# 2                      1.32   1990         June
#
# [3 rows x 27 columns]

# %%
df.head(2)
# Out:
#             Coarse wool Price  Coarse wool price % Change  Copra Price  \
# Month
# 1990-04-01             482.34                        0.00        236.0
# 1990-05-01             447.26                        7.27        234.0
#
#             Copra price % Change  Cotton Price  Cotton price % Change  \
# Month
# 1990-04-01                  0.00          1.83                   0.00
# 1990-05-01                  0.85          1.89                   3.28
#
#             Fine wool Price  Fine wool price % Change  Hard log Price  \
# Month
# 1990-04-01          1071.63                      0.00          161.20
# 1990-05-01          1057.18                      1.35          172.86
#
#             Hard log price % Change  ...  Plywood Price  \
# Month                                ...
# 1990-04-01                     0.00  ...         312.36
# 1990-05-01                     7.23  ...         350.12
#
#             Plywood price % Change  Rubber Price  Rubber price % Change  \
# Month
# 1990-04-01                    0.00          0.84                   0.00
# 1990-05-01                   12.09          0.85                   1.19
#
#             Softlog Price  Softlog price % Change  Soft sawnwood Price  \
# Month
# 1990-04-01         120.66                     0.0               218.76
# 1990-05-01         124.28                     3.0               213.00
#
#             Soft sawnwood price % Change  Wood pulp Price  \
# Month
# 1990-04-01                          0.00           829.29
# 1990-05-01                          2.63           842.51
#
#             Wood pulp price % Change
# Month
# 1990-04-01                      0.00
# 1990-05-01                      1.59
#
# [2 rows x 24 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 361 entries, 1990-04-01 to 2020-04-01
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Coarse wool Price             361 non-null    float64
#  1   Coarse wool price % Change    361 non-null    float64
#  2   Copra Price                   361 non-null    float64
#  3   Copra price % Change          361 non-null    float64
#  4   Cotton Price                  361 non-null    float64
#  5   Cotton price % Change         361 non-null    float64
#  6   Fine wool Price               361 non-null    float64
#  7   Fine wool price % Change      361 non-null    float64
#  8   Hard log Price                361 non-null    float64
#  9   Hard log price % Change       361 non-null    float64
#  10  Hard sawnwood Price           361 non-null    float64
#  11  Hard sawnwood price % Change  361 non-null    float64
#  12  Hide Price                    361 non-null    float64
#  13  Hide price % change           361 non-null    float64
#  14  Plywood Price                 361 non-null    float64
#  15  Plywood price % Change        361 non-null    float64
#  16  Rubber Price                  361 non-null    float64
#  17  Rubber price % Change         361 non-null    float64
#  18  Softlog Price                 361 non-null    float64
#  19  Softlog price % Change        361 non-null    float64
#  20  Soft sawnwood Price           361 non-null    float64
#  21  Soft sawnwood price % Change  361 non-null    float64
#  22  Wood pulp Price               361 non-null    float64
#  23  Wood pulp price % Change      361 non-null    float64
# dtypes: float64(24)
# memory usage: 70.5 KB
