# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv('charts.csv')

# %%
df
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  object
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.6+ MB

# %%
df['date']=pd.DatetimeIndex(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
df['song'].apply(lambda x:str.upper(x))
# Out:
# 0                                  EASY ON ME
# 1                                        STAY
# 2                               INDUSTRY BABY
# 3                                  FANCY LIKE
# 4                                  BAD HABITS
#                          ...
# 330082                          OVER AND OVER
# 330083                       I BELIEVE IN YOU
# 330084                        LITTLE SERENADE
# 330085    I'LL GET BY (AS LONG AS I HAVE YOU)
# 330086                                   JUDY
# Name: song, Length: 330087, dtype: object

# %%
df.columns=['Date', 'Rank', 'Songs', 'Artist', 'Last-Week', 'Peak-Rank',
       'Weeks-on-Board']

# %%
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 330082    January
# 330083    January
# 330084    January
# 330085    January
# 330086    January
# Name: Date, Length: 330087, dtype: object

# %%
df['Date']=pd.DatetimeIndex(df['Date']).year

# %%
# Out:
#            Date  Rank                                Songs  \
# 0       January     1                           Easy On Me
# 1       January     2                                 Stay
# 2       January     3                        Industry Baby
# 3       January     4                           Fancy Like
# 4       January     5                           Bad Habits
# ...         ...   ...                                  ...
# 330082  January    96                        Over And Over
# 330083  January    97                     I Believe In You
# 330084  January    98                      Little Serenade
# 330085  January    99  I'll Get By (As Long As I Have You)
# 330086  January   100                                 Judy
#
#                                Artist  Last-Week  Peak-Rank  Weeks-on-Board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
dframe=pd.read_csv('charts.csv')

# %%
dframe
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  object
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.6+ MB

# %%
dframe['date']=pd.DatetimeIndex(dframe['date']).year

# %%
dframe
# Out:
#         date  rank                                 song  \
# 0       2021     1                           Easy On Me
# 1       2021     2                                 Stay
# 2       2021     3                        Industry Baby
# 3       2021     4                           Fancy Like
# 4       2021     5                           Bad Habits
# ...      ...   ...                                  ...
# 330082  1958    96                        Over And Over
# 330083  1958    97                     I Believe In You
# 330084  1958    98                      Little Serenade
# 330085  1958    99  I'll Get By (As Long As I Have You)
# 330086  1958   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
dframe.columns=['Year','Rank','Songs','Artist','LastWeek','PeakRank','Weeks-on-Board']

# %%
df=dframe.groupby(by=['Year','Songs']).sum()[['LastWeek','PeakRank','Weeks-on-Board']]

# %%
df=df.reset_index()

# %%
twentyone=df[df['Year']==2021]

# %%
subplot=df.groupby('Year')['LastWeek'].sum().plot(kind='barh',figsize=(16,10),color='#098721')
for i in subplot.patches:
    subplot.text(i.get_width()+.30,i.get_y()+.1,\
            str(i.get_width()),fontsize=10,color='#000000')
plt.tight_layout()

# %%
dframe.isnull().sum()
# Out:
# Year                  0
# Rank                  0
# Songs                 0
# Artist                0
# LastWeek          32312
# PeakRank              0
# Weeks-on-Board        0
# dtype: int64

# %%
dframe['LastWeek'].fillna(dframe['LastWeek'].mean(),inplace=True)

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            330087 non-null  int64
#  1   Rank            330087 non-null  int64
#  2   Songs           330087 non-null  object
#  3   Artist          330087 non-null  object
#  4   LastWeek        330087 non-null  float64
#  5   PeakRank        330087 non-null  int64
#  6   Weeks-on-Board  330087 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 17.6+ MB

# %%
df=dframe.groupby(by=['Year','LastWeek']).size().reset_index()

# %%
df.columns=['Year', 'LastWeek', 'Envolved']

# %%
df=df.set_index('Year')

# %%
df
# Out:
#       LastWeek  Envolved
# Year
# 1958       1.0        21
# 1958       2.0        21
# 1958       3.0        21
# 1958       4.0        21
# 1958       5.0        22
# ...        ...       ...
# 2021      96.0        28
# 2021      97.0        21
# 2021      98.0        18
# 2021      99.0        16
# 2021     100.0        16
#
# [6464 rows x 2 columns]

# %%
dframe.tail(5)
# Out:
#         Year  Rank                                Songs             Artist  \
# 330082  1958    96                        Over And Over    Thurston Harris
# 330083  1958    97                     I Believe In You    Robert & Johnny
# 330084  1958    98                      Little Serenade  The Ames Brothers
# 330085  1958    99  I'll Get By (As Long As I Have You)     Billy Williams
# 330086  1958   100                                 Judy    Frankie Vaughan
#
#          LastWeek  PeakRank  Weeks-on-Board
# 330082  47.591631        96               1
# 330083  47.591631        97               1
# 330084  47.591631        98               1
# 330085  47.591631        99               1
# 330086  47.591631       100               1

# %%
dff=pd.DataFrame(dframe.groupby(by=['Year','Songs']).sum()['Weeks-on-Board'])

# %%
dff=dff.reset_index()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(17,9),dpi=190)
sns.countplot(data=dff,x='Year');
plt.xticks(rotation='90');

# %%
dff['Year'].value_counts()
# Out:
# 1966    803
# 1967    802
# 2020    792
# 1964    786
# 1965    773
#        ...
# 2003    399
# 2002    398
# 2004    393
# 2001    384
# 1958    338
# Name: Year, Length: 64, dtype: int64

# %%
# Out:
# 'C:\\Users\\HP'

# %%
df
# Out:
#       LastWeek  Envolved
# Year
# 1958       1.0        21
# 1958       2.0        21
# 1958       3.0        21
# 1958       4.0        21
# 1958       5.0        22
# ...        ...       ...
# 2021      96.0        28
# 2021      97.0        21
# 2021      98.0        18
# 2021      99.0        16
# 2021     100.0        16
#
# [6464 rows x 2 columns]

# %%
dframe
# Out:
#         Year  Rank                                Songs  \
# 0       2021     1                           Easy On Me
# 1       2021     2                                 Stay
# 2       2021     3                        Industry Baby
# 3       2021     4                           Fancy Like
# 4       2021     5                           Bad Habits
# ...      ...   ...                                  ...
# 330082  1958    96                        Over And Over
# 330083  1958    97                     I Believe In You
# 330084  1958    98                      Little Serenade
# 330085  1958    99  I'll Get By (As Long As I Have You)
# 330086  1958   100                                 Judy
#
#                                Artist   LastWeek  PeakRank  Weeks-on-Board
# 0                               Adele   1.000000         1               3
# 1       The Kid LAROI & Justin Bieber   2.000000         1              16
# ...

# %%
dframe[dframe['Rank']!=dframe['PeakRank']]
# Out:
#         Year  Rank                         Songs  \
# 1       2021     2                          Stay
# 2       2021     3                 Industry Baby
# 3       2021     4                    Fancy Like
# 4       2021     5                    Bad Habits
# 5       2021     6                    Way 2 Sexy
# ...      ...   ...                           ...
# 329967  1958    81  Young And Warm And Wonderful
# 329976  1958    90                 Don't Go Home
# 329977  1958    91     All I Have To Do Is Dream
# 329984  1958    98               Gotta Have Rain
# 329986  1958   100    Baubles, Bangles And Beads
#
#                                      Artist  LastWeek  PeakRank  \
# 1             The Kid LAROI & Justin Bieber       2.0         1
# 2                   Lil Nas X & Jack Harlow       3.0         1
# 3                              Walker Hayes       4.0         3
# 4                                Ed Sheeran       5.0         2
# ...

# %%
plt.figure(figsize=(16,8),dpi=100)
sns.kdeplot(data=dframe,x='Rank',clip=[0,100],label='By_Rank',fill=True);
sns.kdeplot(data=dframe,x='PeakRank',clip=[0,100],label='By_Peak_Rank',fill=True);

plt.legend(loc='best')

# %%
dframe
# Out:
#         Year  Rank                                Songs  \
# 0       2021     1                           Easy On Me
# 1       2021     2                                 Stay
# 2       2021     3                        Industry Baby
# 3       2021     4                           Fancy Like
# 4       2021     5                           Bad Habits
# ...      ...   ...                                  ...
# 330082  1958    96                        Over And Over
# 330083  1958    97                     I Believe In You
# 330084  1958    98                      Little Serenade
# 330085  1958    99  I'll Get By (As Long As I Have You)
# 330086  1958   100                                 Judy
#
#                                Artist   LastWeek  PeakRank  Weeks-on-Board
# 0                               Adele   1.000000         1               3
# 1       The Kid LAROI & Justin Bieber   2.000000         1              16
# ...

# %%
plt.figure(figsize=(19,9),dpi=100)
sns.countplot(data=dframe,x='Year');
plt.xticks(rotation=90);

# %%
dframe['Year'].value_counts()
# Out:
# 2005    5300
# 2011    5300
# 2000    5300
# 1988    5300
# 1972    5300
#         ...
# 1991    5200
# 1960    5200
# 1976    5196
# 2021    4500
# 1958    2200
# Name: Year, Length: 64, dtype: int64

# %%
num=dframe.select_dtypes('number')

# %%
plt.figure(figsize=(17,9),dpi=100)
sns.histplot(num,bins=100);

# %%
num.hist(figsize=(14,9),color='#129391');
plt.tight_layout(pad=1)
